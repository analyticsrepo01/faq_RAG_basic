# %% [markdown]
# ### setup

# %%
import socket
import re

PROJECT_ID = !(gcloud config get-value core/project)
PROJECT_ID = PROJECT_ID[0]

SVC_ACC = !(gcloud config get-value core/account)
SVC_ACC = SVC_ACC[0]

PROJECT_NUMBER=str(re.search(r'\d+', SVC_ACC).group())

LOCATION="us-central1"

UNIQUE_PREFIX = socket.gethostname()
UNIQUE_PREFIX = re.sub('[^A-Za-z0-9]+', '', UNIQUE_PREFIX)

BUCKET_NAME = f"{PROJECT_ID}-{UNIQUE_PREFIX}-{LOCATION}"

BUCKET_URI = f"gs://{BUCKET_NAME}"  # @param {type:"string"}

! gcloud config set project $PROJECT_ID
! gcloud storage buckets create {BUCKET_URI} --project={PROJECT_ID} --location={LOCATION}
! mkdir output

import vertexai

vertexai.init(project=PROJECT_ID, location=LOCATION, staging_bucket=BUCKET_URI)
# Out:
# Updated property [core/project].
# Creating gs://my-project-0004-346516-pytorch112kagglewbi-us-central1/...
# ERROR: (gcloud.storage.buckets.create) HTTPError 409: Your previous request to create the named bucket succeeded and you already own it.
# mkdir: cannot create directory ‘output’: File exists

# %% [markdown]
# ### setup gemini models etc...

# %%
# from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_vertexai import VertexAI
from langchain_google_vertexai import VertexAIEmbeddings


# from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
import os 
from dotenv import load_dotenv
load_dotenv()

db_file_path='FAISS_Index'
embeddings = VertexAIEmbeddings('textembedding-gecko@latest')

def creation_of_vectorDB_in_local(loader):
    data = loader.load()
    db =FAISS.from_documents(data, embeddings)
    db.save_local(db_file_path)

def creation_FAQ_chain():
    db=FAISS.load_local(db_file_path, embeddings)
    retriever =db.as_retriever(score_threshold=0.7)
    
    # llm = ChatGoogleGenerativeAI(model="gemini-pro",temperature=0.2)

    # To use model
    llm = VertexAI(model_name="gemini-pro")

    prompt_temp="""Given the following context and a question, generate an answer based on this context only.
    In the answer try to provide as much text as possible from "response" section in the source document context without making much changes.
    If the answer is not found in the context, kindly state "This Question not Present in My Database." Don't try to make up an answer.
    CONTEXT: {context}
    QUESTION: {question}"""

    PROMPT = PromptTemplate(template=prompt_temp, input_variables=["context", "question"])
    chain = RetrievalQA.from_chain_type(llm=llm,chain_type="stuff", 
                                        retriever=retriever, 
                                        input_key="query", 
                                        return_source_documents=False,
                                        chain_type_kwargs={"prompt" : PROMPT})
    return chain

# %% [markdown]
# ### connect to FAQ Datastore

# %%
#@title ### You will need to update these values

import vertexai
vertexai.init(project=PROJECT_ID, location=LOCATION)

DATA_STORE_ID = "faq-ds_1715661604491"  # @param {type:"string"}
DATA_STORE_LOCATION = "global"  # @param {type:"string"}

MODEL = "gemini-1.0-pro"  # @param {type:"string"}

if PROJECT_ID == "YOUR_PROJECT_ID" or DATA_STORE_ID == "YOUR_DATA_STORE_ID":
    raise ValueError(
        "Please set the PROJECT_ID, DATA_STORE_ID constants to reflect your environment."
    )

# %%
###

# %%
from langchain.chains import RetrievalQA
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate

from langchain_google_vertexai import VertexAI
from langchain_google_community import VertexAISearchRetriever
from langchain_google_community import VertexAIMultiTurnSearchRetriever

# %%
llm = VertexAI(model_name=MODEL)

retriever = VertexAISearchRetriever(
    project_id=PROJECT_ID,
    location_id=DATA_STORE_LOCATION,
    data_store_id=DATA_STORE_ID,
    get_extractive_answers=True,
    max_documents=10,
    max_extractive_segment_count=1,
    max_extractive_answer_count=5,
)

# %%
search_query = "How do I track my package on the portal"  # @param {type:"string"}

retrieval_qa = RetrievalQA.from_chain_type(
    llm=llm, chain_type="stuff", retriever=retriever
)
retrieval_qa.invoke(search_query)
# Out:
# {'query': 'How do I track my package on the portal',
#  'result': '## How to Track Your Package on the Portal\n\nBased on the provided information, there are two ways to track your package on the portal:\n\n1. **From the Ready to Ship list:** After completing the SED declaration, the item will be available in the **Ready to Ship list**. This list can be accessed through the following steps:\n    * Go to the **Package Summary** section (link: https://drive.google.com/file/d/14-ELQYg19D3ypTZDspqKnk6PcGucs8Qu/view?usp=drive_link).\n    * Click on the **SED** tab.\n    * Find the item you are looking for in the **Ready to Ship list**.\n    * Click on the **Tracking** link next to the item.\n\n2. **From the Package Summary:** You can also track your package directly from the **Package Summary** section. To do this:\n    * Go to the **Package Summary** section (link: https://drive.google.com/file/d/14-ELQYg19D3ypTZDspqKnk6PcGucs8Qu/view?usp=drive_link).\n    * Find the package you are looking for.\n    * Click on the **Tracking** link next to the package.\n\nBoth methods will take you to the tracking page, where you can see the current status of your package.\n\n**Note:** The images you provided are not publicly accessible. To access them, I would need to be granted access to your Google Drive.\n'}

# %%
import pandas as pd

# Replace 'your_file.csv' with the actual filename
df = pd.read_csv('Singpost_QnA_doc.csv')

questions_list = df["question"].tolist()

# print(questions_list)
# Out:
# ['I need to update my email address', 'How do I get my package shipped', 'How do I navigate the members portal', 'How do I navigate the address section on the portal', 'How do I perform declaration on my package', 'What is SED and what does the customer need to do?', 'How do I navigate the package summary', 'How do I track my package on the portal', 'What kind of cases can CS Ops assist?', 'What kind of case can vPost FFPs assist with?', 'Which team can provide assistance for unclaimed vPost packages', 'Is bundling discount available?', 'What is VP ID']

# %%
df["all_ans_type1"] = [    retrieval_qa.invoke(quest_i) for quest_i in questions_list ]

# %%
# all_ans = [] 
# for quest_i in questions_list: 
#     ans = retrieval_qa.invoke(quest_i)
#     all_ans += ans
#     # print(ans)

# %% [markdown]
# ### TYPE 2

# %%
retrieval_qa_with_sources = RetrievalQAWithSourcesChain.from_chain_type(
    llm=llm, chain_type="stuff", retriever=retriever
)

retrieval_qa_with_sources.invoke(search_query, return_only_outputs=False)
# Out:
# {'question': 'How do I track my package on the portal',
#  'answer': "I apologize, but the text you've provided doesn't include instructions on how to track your package on the portal. Please provide more information or specific instructions on how to track your package on the portal, and I'd be happy to help!\n",
#  'sources': ''}

# %%
# questions_list
# Out:
# ['I need to update my email address',
#  'How do I get my package shipped',
#  'How do I navigate the members portal',
#  'How do I navigate the address section on the portal',
#  'How do I perform declaration on my package',
#  'What is SED and what does the customer need to do?',
#  'How do I navigate the package summary',
#  'How do I track my package on the portal',
#  'What kind of cases can CS Ops assist?',
#  'What kind of case can vPost FFPs assist with?',
#  'Which team can provide assistance for unclaimed vPost packages',
#  'Is bundling discount available?',
#  'What is VP ID']

# %%
df["all_ans_type2"] = [    retrieval_qa_with_sources.invoke(quest_i) for quest_i in questions_list ]

# %%
df
# Out:
#                                              question  \
# 0                   I need to update my email address
# 1                     How do I get my package shipped
# 2                How do I navigate the members portal
# 3   How do I navigate the address section on the p...
# 4          How do I perform declaration on my package
# 5   What is SED and what does the customer need to...
# 6               How do I navigate the package summary
# 7             How do I track my package on the portal
# 8               What kind of cases can CS Ops assist?
# 9       What kind of case can vPost FFPs assist with?
# 10  Which team can provide assistance for unclaime...
# 11                    Is bundling discount available?
# 12                                      What is VP ID
#
#                                                answer  \
# 0   As each account is tied to a unique email addr...
# 1   Your unique VP ID that forms part of your over...
# 2   Refer to the following image(s) https://drive....
# 3   Refer to the following image(s) https://drive....
# 4   Refer to the following image(s) https://drive....
# 5   SED refers to the United States Shipper’s Expo...
# 6   Refer to the following image(s) https://drive....
# 7   Refer to the following image(s) https://drive....
# 8   Item matched to wrong VP number (provide suppo...
# 9   1. Request to match to correct owner / Item ta...
# 10                  SG-Parcel Teams-Return Management
# 11  Bundling Discount is only offered to vPost SG ...
# 12                                                NaN
#
#                                         all_ans_type2  \
# 0   {'question': 'I need to update my email addres...
# 1   {'question': 'How do I get my package shipped'...
# 2   {'question': 'How do I navigate the members po...
# 3   {'question': 'How do I navigate the address se...
# 4   {'question': 'How do I perform declaration on ...
# 5   {'question': 'What is SED and what does the cu...
# 6   {'question': 'How do I navigate the package su...
# 7   {'question': 'How do I track my package on the...
# 8   {'question': 'What kind of cases can CS Ops as...
# 9   {'question': 'What kind of case can vPost FFPs...
# 10  {'question': 'Which team can provide assistanc...
# 11  {'question': 'Is bundling discount available?'...
# 12  {'question': 'What is VP ID', 'answer': 'VP ID...
#
#                                         all_ans_type1
# 0   {'query': 'I need to update my email address',...
# 1   {'query': 'How do I get my package shipped', '...
# 2   {'query': 'How do I navigate the members porta...
# 3   {'query': 'How do I navigate the address secti...
# 4   {'query': 'How do I perform declaration on my ...
# 5   {'query': 'What is SED and what does the custo...
# 6   {'query': 'How do I navigate the package summa...
# 7   {'query': 'How do I track my package on the po...
# 8   {'query': 'What kind of cases can CS Ops assis...
# 9   {'query': 'What kind of case can vPost FFPs as...
# 10  {'query': 'Which team can provide assistance f...
# 11  {'query': 'Is bundling discount available?', '...
# 12  {'query': 'What is VP ID', 'result': '## What ...

# %%
# df["all_ans_type2"][0]
# Out:
# {'query': 'I need to update my email address',
#  'result': "I'm sorry, but you cannot update the email address associated with your account. To change your email address, you will need to create a new account."}

# %% [markdown]
# ### Type 3

# %%
from google.cloud import discoveryengine_v1alpha as discoveryengine

# %%
SEARCH_APP_LOCATION = "global"  # @param {type:"string"}
SEARCH_ENGINE_ID = "faq-app_1715661153113"  # @param {type:"string"}

# %%
search_query = "How do I get my package shipped?"

# %%
# Create a client using a regional endpoint
client = discoveryengine.SearchServiceClient(
    client_options=(
        ClientOptions(
            api_endpoint=f"{SEARCH_APP_LOCATION}-discoveryengine.googleapis.com"
        )
        if SEARCH_APP_LOCATION != "global"
        else None
    )
)

# The full resource name of the search app serving config
serving_config = f"projects/{PROJECT_ID}/locations/{SEARCH_APP_LOCATION}/collections/default_collection/engines/{SEARCH_ENGINE_ID}/servingConfigs/default_config"

response = client.search(
    discoveryengine.SearchRequest(
        serving_config=serving_config,
        query=search_query,
        page_size=10,
    )
)

# %%
response
# Out:
# SearchPager<results {
#   id: "be88ac33cbb68d7b5309767940eb0989"
#   document {
#     name: "projects/255766800726/locations/global/collections/default_collection/dataStores/faq-ds_1715661604491/branches/0/documents/be88ac33cbb68d7b5309767940eb0989"
#     id: "be88ac33cbb68d7b5309767940eb0989"
#     struct_data {
#       fields {
#         key: "answer"
#         value {
#           string_value: "Your unique VP ID that forms part of your overseas address is very important as it helps us to identify your package. Please ensure it is in your address fdields as shown. In the event you are not bale to enter the VP ID as part of your name, you may indicate the VP ID in other parts of the address"
#         }
#       }
#       fields {
#         key: "question"
#         value {
#           string_value: "How do I get my package shipped"
#         }
#       }
#     }
#     derived_struct_data {
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "In the event you are not bale to enter the VP ID as part of your name, you may indicate the VP ID in other parts of the address."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "How do I get my package shipped"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "6527a08aec1bfacd66489df8cbd301c2"
#   document {
#     name: "projects/255766800726/locations/global/collections/default_collection/dataStores/faq-ds_1715661604491/branches/0/documents/6527a08aec1bfacd66489df8cbd301c2"
#     id: "6527a08aec1bfacd66489df8cbd301c2"
#     struct_data {
#       fields {
#         key: "answer"
#         value {
#           string_value: "Refer to the following image(s) https://drive.google.com/file/d/14AghVyef_uIh6E3xpH04dWn4fbzzzW-g/view?usp =drive_link https://drive.google.com/file/d/14FNpFwhJPJWKvlFSfwz0n3myqMpFNYl-/view?us p=drive_link"
#         }
#       }
#       fields {
#         key: "question"
#         value {
#           string_value: "How do I track my package on the portal"
#         }
#       }
#     }
#     derived_struct_data {
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "How do I track my package on the portal Refer to the following image(s) https://drive.google.com/file/d/14AghVyef_uIh6E3xpH04dWn4fbzzzW-g/view?usp =drive_link https://drive.google.com/file/d/14FNpFwhJPJWKvlFSfwz0n3myqMpFNYl-/view?us p=drive_link."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "How do I track my package on the portal"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "78f30f97c014227d2a332c44dfc16b68"
#   document {
#     name: "projects/255766800726/locations/global/collections/default_collection/dataStores/faq-ds_1715661604491/branches/0/documents/78f30f97c014227d2a332c44dfc16b68"
#     id: "78f30f97c014227d2a332c44dfc16b68"
#     struct_data {
#       fields {
#         key: "answer"
#         value {
#           string_value: "Refer to the following image(s) https://drive.google.com/file/d/13s1ZvIMYdisHSyP1vUhSsbUJiljgImfe/view?usp=dr ive_link https://drive.google.com/file/d/13xMGpNy7NLzfXxgxSpNaKxBCzTYcfM66/view?us p=drive_link"
#         }
#       }
#       fields {
#         key: "question"
#         value {
#           string_value: "How do I perform declaration on my package"
#         }
#       }
#     }
#     derived_struct_data {
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "How do I perform declaration on my package Refer to the following image(s) https://drive.google.com/file/d/13s1ZvIMYdisHSyP1vUhSsbUJiljgImfe/view?usp=dr ive_link https://drive.google.com/file/d/13xMGpNy7NLzfXxgxSpNaKxBCzTYcfM66/view?us p=drive_link."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "How do I perform declaration on my package"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "8fdb65d1b6ff26c727bcc316afb6d968"
#   document {
#     name: "projects/255766800726/locations/global/collections/default_collection/dataStores/faq-ds_1715661604491/branches/0/documents/8fdb65d1b6ff26c727bcc316afb6d968"
#     id: "8fdb65d1b6ff26c727bcc316afb6d968"
#     struct_data {
#       fields {
#         key: "answer"
#         value {
#           string_value: "SED refers to the United States Shipper\342\200\231s Export Declaration. Any export or shipment out of USA that exceeds USD2500 requires a SED to be submitted as required by U.S. Customs and Border Protection To make a SED declaration refer to the infographic below. The item will be available in the Ready to Ship list once the SED declaration is completed. https://drive.google.com/file/d/13zft46GJQk12zVN7sh3Bqp2qenOE7sco/view?usp =drive_link"
#         }
#       }
#       fields {
#         key: "question"
#         value {
#           string_value: "What is SED and what does the customer need to do?"
#         }
#       }
#     }
#     derived_struct_data {
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "The item will be available in the Ready to Ship list once the SED declaration is completed. https://drive.google.com/file/d/13zft46GJQk12zVN7sh3Bqp2qenOE7sco/view?usp =drive_link."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "What is SED and what does the customer need to do?"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "08d3e49b62702f2a1df375f75de02c85"
#   document {
#     name: "projects/255766800726/locations/global/collections/default_collection/dataStores/faq-ds_1715661604491/branches/0/documents/08d3e49b62702f2a1df375f75de02c85"
#     id: "08d3e49b62702f2a1df375f75de02c85"
#     struct_data {
#       fields {
#         key: "answer"
#         value {
#           string_value: "1. Request to match to correct owner / Item tagged to wrong account 2. Check why item was classified as DG-partial/full DG items \342\200\223 list down the items that is considered DG and take picture of those items. 3. Discard request to be sent to FFP. FFP will discard and update CS. CS to send case to vPost Ops to delete the item from customer\342\200\231s account. 4. Repacking 5. Reweigh/re-measure \342\200\223 dispute of shipping fee. If item still in FFP \342\200\223 send to FFP. Item already in Singapore \342\200\223 customer to reweigh/remeasure. 6. Item delivered and beyond 48 hours and not in unassigned package in admin module. 7. Partial DG. a. FFP will take out the non-DG item and put it into a new box. b. FFP will keep the DG item into the original box either to return to merchant or any other instructions from customer. c. CS to update vPost Ops that this has been done. 8. On Hold item status 9. Redirection request (Computation, etc)"
#         }
#       }
#       fields {
#         key: "question"
#         value {
#           string_value: "What kind of case can vPost FFPs assist with?"
#         }
#       }
#     }
#     derived_struct_data {
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "3. Discard request to be sent to FFP. FFP will discard and update CS. CS to send case to vPost Ops to delete the item from customer&#39;s account. 4. Repacking 5. Reweigh/re-measure \342\200\223 dispute of shipping fee."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "What kind of case can vPost FFPs assist with?"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "b87c3fb216e4d9b3d9714232610778c5"
#   document {
#     name: "projects/255766800726/locations/global/collections/default_collection/dataStores/faq-ds_1715661604491/branches/0/documents/b87c3fb216e4d9b3d9714232610778c5"
#     id: "b87c3fb216e4d9b3d9714232610778c5"
#     struct_data {
#       fields {
#         key: "answer"
#         value {
#           string_value: "Refer to the following image(s) https://drive.google.com/file/d/14-ELQYg19D3ypTZDspqKnk6PcGucs8Qu/view?usp =drive_link"
#         }
#       }
#       fields {
#         key: "question"
#         value {
#           string_value: "How do I navigate the package summary"
#         }
#       }
#     }
#     derived_struct_data {
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "How do I navigate the package summary Refer to the following image(s) https://drive.google.com/file/d/14-ELQYg19D3ypTZDspqKnk6PcGucs8Qu/view?usp =drive_link."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "How do I navigate the package summary"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "c5759a45095dabde28349cfb9861d015"
#   document {
#     name: "projects/255766800726/locations/global/collections/default_collection/dataStores/faq-ds_1715661604491/branches/0/documents/c5759a45095dabde28349cfb9861d015"
#     id: "c5759a45095dabde28349cfb9861d015"
#     struct_data {
#       fields {
#         key: "answer"
#         value {
#           string_value: "SG-Parcel Teams-Return Management"
#         }
#       }
#       fields {
#         key: "question"
#         value {
#           string_value: "Which team can provide assistance for unclaimed vPost packages"
#         }
#       }
#     }
#     derived_struct_data {
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "Which team can provide assistance for unclaimed vPost packages SG-Parcel Teams-Return Management."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "Which team can provide assistance for unclaimed vPost packages"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "050be6b906f77518a1f0c0fe018e1e2b"
#   document {
#     name: "projects/255766800726/locations/global/collections/default_collection/dataStores/faq-ds_1715661604491/branches/0/documents/050be6b906f77518a1f0c0fe018e1e2b"
#     id: "050be6b906f77518a1f0c0fe018e1e2b"
#     struct_data {
#       fields {
#         key: "answer"
#         value {
#           string_value: "Item matched to wrong VP number (provide supporting documents \342\200\223 e.g. merchant\342\200\231s invoice and tracking no. or Proof of delivery) 2. Advised by FFP that item cannot be located at warehouse. 3. Check if item can be shipped (items not on prohibited list at vPost website) 4. Item repacked by FFP but new weight/dimensions are not updated in vPost Admin module. 5. Completed SED forms from customer (Applicable to vPost USA ONLY). 6. Non receipt of email notification 7. Update record in vPost system after FFP discarded the / returned to merchant / collected by 3rd party courier and redirected 8. If \342\200\234On Hold\342\200\235 > D+1, we will escalate to vPost Ops 9. To create dummy boxes for redirection/return to merchant request Mismatch of con-note, item retrieved from customer to create a dummy invoice for the correct customer to pay. 10. Duplicate payment for investigation and other payment related issues in customer\'s account 11. Termination request 12. Customer unable to log in to their accounts (cases should be forwarded to this queue only when CS has tried all necessary methods to assist customers) 13. General vPost account issues include technical issues. 14. SPSTAFF code (for SingPost colleagues who are enquiring about this code, please route to this queue, with the necessary information) 15. Voucher code and coupon issues. (Interim queue)"
#         }
#       }
#       fields {
#         key: "question"
#         value {
#           string_value: "What kind of cases can CS Ops assist?"
#         }
#       }
#     }
#     derived_struct_data {
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "Non receipt of email notification 7. Update record in vPost system after FFP discarded the / returned to merchant / collected by 3rd party courier and redirected 8."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "What kind of cases can CS Ops assist?"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "09b899da67f981eda1557bd96298cdf3"
#   document {
#     name: "projects/255766800726/locations/global/collections/default_collection/dataStores/faq-ds_1715661604491/branches/0/documents/09b899da67f981eda1557bd96298cdf3"
#     id: "09b899da67f981eda1557bd96298cdf3"
#     struct_data {
#       fields {
#         key: "answer"
#         value {
#           string_value: "Bundling Discount is only offered to vPost SG Customers only. The lowest-priced package will automatically be selected as the first Package to provide maximum discount and value. Discount will apply only on the second and subsequent packages Bunding discount applies when customer ship multiple package in one shipment."
#         }
#       }
#       fields {
#         key: "question"
#         value {
#           string_value: "Is bundling discount available?"
#         }
#       }
#     }
#     derived_struct_data {
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "Is bundling discount available?"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "title"
#         value {
#           string_value: "Is bundling discount available?"
#         }
#       }
#     }
#   }
# }
# results {
#   id: "0dcfddef761a45fbd67e34e70525f3de"
#   document {
#     name: "projects/255766800726/locations/global/collections/default_collection/dataStores/faq-ds_1715661604491/branches/0/documents/0dcfddef761a45fbd67e34e70525f3de"
#     id: "0dcfddef761a45fbd67e34e70525f3de"
#     struct_data {
#       fields {
#         key: "answer"
#         value {
#           string_value: ""
#         }
#       }
#       fields {
#         key: "question"
#         value {
#           string_value: "What is VP ID"
#         }
#       }
#     }
#     derived_struct_data {
#       fields {
#         key: "title"
#         value {
#           string_value: "What is VP ID"
#         }
#       }
#     }
#   }
# }
# total_size: 13
# attribution_token: "jwHwjgoMCOWbjLIGEIanm44CEiQ2NjQ0NGRmZC0wMDAwLTIxZDctOTQwZC0wODllMDgyZTExNzAiB0dFTkVSSUMqUK7Eii3bj5oijr6dFdSynRWN96ci3u2ILZD3pyKjgJcixcvzF8LwnhXn7Ygtt7eMLd6PmiL37Igtq8SKLYOymiLb7Ygt5O2ILfrsiC2Aspoi"
# next_page_token: "AzNxETZygDMllDOw0CZwQTOtcDZxITLwADMw0yYmRGN0QjN2QiGC8ssYXIEGILnEWOCMIBMxIgC"
# guided_search_result {
# }
# summary {
# }
# >

# %% [markdown]
# ### helper function -- just in case

# %%
# !gsutil cp  ./Singpost_QnA_doc.csv gs://my-project-0004-bucket02/llms
